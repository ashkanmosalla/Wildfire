# %% [markdown]
# # Canada Wildfire Project

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Load Data

# %%
train = pd.read_csv('Training_data.csv')

# %%
train.head()
# Out:
#    OBJECTID  Training_fire_point             X             Y    twi  \
# 0         1                    1  9.779328e+05 -171014.66810   -6.0
# 1         2                    1  1.347033e+06  -80014.66811   -6.0
# 2         3                    1  9.444328e+05  -50014.66811  129.0
# 3         4                    1  9.470328e+05  -50814.66811   -6.0
# 4         5                    1  9.414328e+05  -51414.66811  -46.0
#
#    tmaxjuly_2  tmax  soilmois  slope  ndvi  lulc  lake  evt_aug  elevation  \
# 0         4.0   5.0       4.0    3.0   5.0   4.0   2.0      5.0        3.0
# 1         4.0   5.0       3.0    3.0   5.0   4.0   4.0      5.0        2.0
# 2         4.0   5.0       3.0    2.0   5.0   4.0   4.0      5.0        3.0
# 3         4.0   5.0       3.0    2.0   5.0   4.0   4.0      5.0        3.0
# 4         4.0   5.0       3.0    2.0   5.0   4.0   4.0      5.0        3.0
#
#    aspect  road  river  pcp
# 0     4.0   2.0    4.0  3.0
# 1     3.0   2.0    4.0  3.0
# 2     6.0   2.0    4.0  3.0
# 3     5.0   2.0    4.0  3.0
# 4     5.0   2.0    4.0  3.0

# %%
test = pd.read_csv('Testing_data.csv')

# %%
test.head()
# Out:
#    OBJECTID  testing_fire_Point             X             Y    twi  \
# 0         1                   1  1.104417e+06 -41066.374270 -219.0
# 1         2                   1  2.347017e+06 -47066.374270   -6.0
# 2         3                   1  2.353017e+06 -47366.374270   -6.0
# 3         4                   1  7.265169e+05   9933.625731  143.0
# 4         5                   1  7.247169e+05   6933.625731  143.0
#
#    tmaxjuly_2  tmax  soilmois  slope  ndvi  lulc  lake  evt_aug  elevation  \
# 0         4.0   5.0       3.0    4.0   5.0     4     4        5        3.0
# 1         3.0   5.0       3.0    2.0   5.0     4     5        4        1.0
# 2         3.0   5.0       3.0    2.0   5.0     4     5        5        1.0
# 3         3.0   4.0       3.0    4.0   5.0     4     3        5        3.0
# 4         3.0   4.0       3.0    4.0   5.0     4     3        5        3.0
#
#    aspect  road  river  pcp
# 0     4.0     2      4  3.0
# 1     4.0     0      5  4.0
# 2     4.0     0      5  4.0
# 3     3.0     1      4  3.0
# 4     3.0     0      4  3.0

# %%
train['Training_fire_point'].value_counts()
# Out:
# 1    14812
# 0    13713
# Name: Training_fire_point, dtype: int64

# %%
test['testing_fire_Point'].value_counts()
# Out:
# 1    3708
# 0    3441
# Name: testing_fire_Point, dtype: int64

# %%
train.shape
# Out:
# (28525, 18)

# %%
test.shape
# Out:
# (7149, 18)

# %%
train.columns
# Out:
# Index(['OBJECTID', 'Training_fire_point', 'X', 'Y', 'twi', 'tmaxjuly_2',
#        'tmax', 'soilmois', 'slope', 'ndvi', 'lulc', 'lake', 'evt_aug',
#        'elevation', 'aspect', 'road', 'river', 'pcp'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['OBJECTID', 'testing_fire_Point', 'X', 'Y', 'twi', 'tmaxjuly_2', 'tmax',
#        'soilmois', 'slope', 'ndvi', 'lulc', 'lake', 'evt_aug', 'elevation',
#        'aspect', 'road', 'river', 'pcp'],
#       dtype='object')

# %%
df_train = pd.read_csv('Training_data.csv', names= ['OBJECTID', 'Wildfire', 'X', 'Y', 'TWI', 'temp_july', 'temp_max', 'soilmois', 
                                                   'slope', 'ndvi', 'lulc', 'dist_lake', 'evt_aug', 'elevation', 'aspect', 'dist_road',
                                                    'dist_river', 'pcp'
                                                   ], header= 0
                      )

# %%
df_train
# Out:
#        OBJECTID  Wildfire             X             Y    TWI  temp_july  \
# 0             1         1  9.779328e+05 -1.710147e+05   -6.0        4.0
# 1             2         1  1.347033e+06 -8.001467e+04   -6.0        4.0
# 2             3         1  9.444328e+05 -5.001467e+04  129.0        4.0
# 3             4         1  9.470328e+05 -5.081467e+04   -6.0        4.0
# 4             5         1  9.414328e+05 -5.141467e+04  -46.0        4.0
# ...         ...       ...           ...           ...    ...        ...
# 28520     28521         0 -1.565730e+06  2.817666e+06  129.0        1.0
# 28521     28522         0 -1.603130e+06  2.835066e+06   -6.0        1.0
# 28522     28523         0 -1.595730e+06  2.834666e+06 -219.0        1.0
# 28523     28524         0 -1.593430e+06  2.829566e+06 -219.0        1.0
# 28524     28525         0 -1.598230e+06  2.829066e+06  129.0        1.0
#
#        temp_max  soilmois  slope  ndvi  lulc  dist_lake  evt_aug  elevation  \
# 0           5.0       4.0    3.0   5.0   4.0        2.0      5.0        3.0
# 1           5.0       3.0    3.0   5.0   4.0        4.0      5.0        2.0
# 2           5.0       3.0    2.0   5.0   4.0        4.0      5.0        3.0
# 3           5.0       3.0    2.0   5.0   4.0        4.0      5.0        3.0
# 4           5.0       3.0    2.0   5.0   4.0        4.0      5.0        3.0
# ...         ...       ...    ...   ...   ...        ...      ...        ...
# 28520       1.0       1.0    2.0   2.0   3.0        5.0      1.0        1.0
# 28521       1.0       1.0    5.0   2.0   5.0        5.0      1.0        2.0
# 28522       1.0       1.0    4.0   2.0   5.0        5.0      1.0        2.0
# 28523       1.0       1.0    5.0   2.0   3.0        5.0      1.0        2.0
# 28524       1.0       1.0    4.0   2.0   8.0        5.0      1.0        2.0
#
#        aspect  dist_road  dist_river  pcp
# 0         4.0        2.0         4.0  3.0
# 1         3.0        2.0         4.0  3.0
# 2         6.0        2.0         4.0  3.0
# 3         5.0        2.0         4.0  3.0
# 4         5.0        2.0         4.0  3.0
# ...       ...        ...         ...  ...
# 28520     2.0        4.0         5.0  1.0
# 28521     6.0        4.0         5.0  1.0
# 28522     3.0        4.0         5.0  1.0
# 28523     5.0        4.0         5.0  1.0
# 28524     2.0        4.0         5.0  1.0
#
# [28525 rows x 18 columns]

# %%
df_test = pd.read_csv('Testing_data.csv', names= ['OBJECTID', 'Wildfire', 'X', 'Y', 'TWI', 'temp_july', 'temp_max', 'soilmois', 
                                                   'slope', 'ndvi', 'lulc', 'dist_lake', 'evt_aug', 'elevation', 'aspect', 'dist_road',
                                                    'dist_river', 'pcp'
                                                   ], header= 0
                      )

# %%
df_test
# Out:
#       OBJECTID  Wildfire             X             Y    TWI  temp_july  \
# 0            1         1  1.104417e+06 -4.106637e+04 -219.0        4.0
# 1            2         1  2.347017e+06 -4.706637e+04   -6.0        3.0
# 2            3         1  2.353017e+06 -4.736637e+04   -6.0        3.0
# 3            4         1  7.265169e+05  9.933626e+03  143.0        3.0
# 4            5         1  7.247169e+05  6.933626e+03  143.0        3.0
# ...        ...       ...           ...           ...    ...        ...
# 7144      7145         0 -1.592123e+06  2.814265e+06 -219.0        1.0
# 7145      7146         0 -1.574423e+06  2.816265e+06  129.0        1.0
# 7146      7147         0 -1.569823e+06  2.816165e+06  129.0        1.0
# 7147      7148         0 -1.590823e+06  2.839065e+06   -6.0        1.0
# 7148      7149         0 -1.592023e+06  2.832865e+06   -6.0        1.0
#
#       temp_max  soilmois  slope  ndvi  lulc  dist_lake  evt_aug  elevation  \
# 0          5.0       3.0    4.0   5.0     4          4        5        3.0
# 1          5.0       3.0    2.0   5.0     4          5        4        1.0
# 2          5.0       3.0    2.0   5.0     4          5        5        1.0
# 3          4.0       3.0    4.0   5.0     4          3        5        3.0
# 4          4.0       3.0    4.0   5.0     4          3        5        3.0
# ...        ...       ...    ...   ...   ...        ...      ...        ...
# 7144       1.0       1.0    5.0   2.0     8          5        1        3.0
# 7145       1.0       1.0    4.0   2.0     5          5        1        2.0
# 7146       1.0       1.0    3.0   2.0     3          5        1        1.0
# 7147       1.0       1.0    3.0   2.0     3          5        1        1.0
# 7148       1.0       1.0    4.0   2.0     5          5        1        2.0
#
#       aspect  dist_road  dist_river  pcp
# 0        4.0          2           4  3.0
# 1        4.0          0           5  4.0
# 2        4.0          0           5  4.0
# 3        3.0          1           4  3.0
# 4        3.0          0           4  3.0
# ...      ...        ...         ...  ...
# 7144     6.0          4           5  1.0
# 7145     3.0          4           5  1.0
# 7146     3.0          4           5  1.0
# 7147     2.0          4           5  1.0
# 7148     2.0          4           5  1.0
#
# [7149 rows x 18 columns]

# %%
df_train.dtypes
# Out:
# OBJECTID        int64
# Wildfire        int64
# X             float64
# Y             float64
# TWI           float64
# temp_july     float64
# temp_max      float64
# soilmois      float64
# slope         float64
# ndvi          float64
# lulc          float64
# dist_lake     float64
# evt_aug       float64
# elevation     float64
# aspect        float64
# dist_road     float64
# dist_river    float64
# pcp           float64
# dtype: object

# %%
df_test.dtypes
# Out:
# OBJECTID        int64
# Wildfire        int64
# X             float64
# Y             float64
# TWI           float64
# temp_july     float64
# temp_max      float64
# soilmois      float64
# slope         float64
# ndvi          float64
# lulc            int64
# dist_lake       int64
# evt_aug         int64
# elevation     float64
# aspect        float64
# dist_road       int64
# dist_river      int64
# pcp           float64
# dtype: object

# %%
{col: df_train[col].nunique() for col in df_train}
# Out:
# {'OBJECTID': 28525,
#  'Wildfire': 2,
#  'X': 19837,
#  'Y': 19220,
#  'TWI': 5,
#  'temp_july': 5,
#  'temp_max': 5,
#  'soilmois': 5,
#  'slope': 5,
#  'ndvi': 5,
#  'lulc': 10,
#  'dist_lake': 5,
#  'evt_aug': 5,
#  'elevation': 5,
#  'aspect': 6,
#  'dist_road': 5,
#  'dist_river': 5,
#  'pcp': 5}

# %%
{col: df_test[col].nunique() for col in df_test}
# Out:
# {'OBJECTID': 7149,
#  'Wildfire': 2,
#  'X': 6435,
#  'Y': 6361,
#  'TWI': 5,
#  'temp_july': 5,
#  'temp_max': 5,
#  'soilmois': 5,
#  'slope': 5,
#  'ndvi': 5,
#  'lulc': 10,
#  'dist_lake': 5,
#  'evt_aug': 5,
#  'elevation': 5,
#  'aspect': 6,
#  'dist_road': 5,
#  'dist_river': 5,
#  'pcp': 5}

# %%
df_train['pcp'].value_counts()
# Out:
# 2.0    12206
# 1.0     8808
# 3.0     5468
# 4.0     1827
# 5.0      210
# Name: pcp, dtype: int64

# %%
df_test['pcp'].value_counts()
# Out:
# 2.0    3052
# 1.0    2259
# 3.0    1333
# 4.0     447
# 5.0      55
# Name: pcp, dtype: int64

# %%
df_train['soilmois'].value_counts()
# Out:
# 1.0    12759
# 2.0     8842
# 3.0     4769
# 4.0     1786
# 5.0      363
# Name: soilmois, dtype: int64

# %%
df_test['soilmois'].value_counts()
# Out:
# 1.0    3221
# 2.0    2212
# 3.0    1212
# 4.0     422
# 5.0      79
# Name: soilmois, dtype: int64

# %%
df_train['aspect'].value_counts()
# Out:
# 3.0    7242
# 5.0    6970
# 4.0    5960
# 6.0    3164
# 2.0    3078
# 1.0    2088
# Name: aspect, dtype: int64

# %%
df_test['aspect'].value_counts()
# Out:
# 3.0    1798
# 5.0    1729
# 4.0    1492
# 6.0     831
# 2.0     770
# 1.0     519
# Name: aspect, dtype: int64

# %%
df_train['aspect'] = df_train['aspect'].replace(6, 2)

# %%
df_train['aspect'].value_counts()
# Out:
# 3.0    7242
# 5.0    6970
# 2.0    6242
# 4.0    5960
# 1.0    2088
# Name: aspect, dtype: int64

# %%
df_test['aspect'] = df_test['aspect'].replace(6, 2)

# %%
df_test['aspect'].value_counts()
# Out:
# 3.0    1798
# 5.0    1729
# 2.0    1601
# 4.0    1492
# 1.0     519
# Name: aspect, dtype: int64

# %%
df_train.columns
# Out:
# Index(['OBJECTID', 'Wildfire', 'X', 'Y', 'TWI', 'temp_july', 'temp_max',
#        'soilmois', 'slope', 'ndvi', 'lulc', 'dist_lake', 'evt_aug',
#        'elevation', 'aspect', 'dist_road', 'dist_river', 'pcp'],
#       dtype='object')

# %%
df_train = df_train.astype(
    {
        'Wildfire': 'category',
        'temp_july': 'category',
        'temp_max': 'category',
        'soilmois': 'category',
        'slope': 'category',
        'ndvi': 'category',
        'lulc': 'category',
        'dist_lake': 'category',
        'evt_aug': 'category',
        'elevation': 'category',
        'aspect': 'category',
        'dist_road': 'category',
        'dist_river': 'category',
        'pcp': 'category',
    }
)

# %%
df_test = df_test.astype(
    {
        'Wildfire': 'category',
        'temp_july': 'category',
        'temp_max': 'category',
        'soilmois': 'category',
        'slope': 'category',
        'ndvi': 'category',
        'lulc': 'category',
        'dist_lake': 'category',
        'evt_aug': 'category',
        'elevation': 'category',
        'aspect': 'category',
        'dist_road': 'category',
        'dist_river': 'category',
        'pcp': 'category',
    }
)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28525 entries, 0 to 28524
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    28525 non-null  int64
#  1   Wildfire    28525 non-null  category
#  2   X           28525 non-null  float64
#  3   Y           28525 non-null  float64
#  4   TWI         28502 non-null  float64
#  5   temp_july   28513 non-null  category
#  6   temp_max    28519 non-null  category
#  7   soilmois    28519 non-null  category
#  8   slope       28502 non-null  category
#  9   ndvi        28522 non-null  category
#  10  lulc        28522 non-null  category
#  11  dist_lake   28523 non-null  category
#  12  evt_aug     28523 non-null  category
#  13  elevation   28502 non-null  category
#  14  aspect      28502 non-null  category
#  15  dist_road   28523 non-null  category
#  16  dist_river  28523 non-null  category
#  17  pcp         28519 non-null  category
# dtypes: category(14), float64(3), int64(1)
# memory usage: 1.3 MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7149 entries, 0 to 7148
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    7149 non-null   int64
#  1   Wildfire    7149 non-null   category
#  2   X           7149 non-null   float64
#  3   Y           7149 non-null   float64
#  4   TWI         7139 non-null   float64
#  5   temp_july   7146 non-null   category
#  6   temp_max    7146 non-null   category
#  7   soilmois    7146 non-null   category
#  8   slope       7139 non-null   category
#  9   ndvi        7146 non-null   category
#  10  lulc        7149 non-null   category
#  11  dist_lake   7149 non-null   category
#  12  evt_aug     7149 non-null   category
#  13  elevation   7139 non-null   category
#  14  aspect      7139 non-null   category
#  15  dist_road   7149 non-null   category
#  16  dist_river  7149 non-null   category
#  17  pcp         7146 non-null   category
# dtypes: category(14), float64(3), int64(1)
# memory usage: 324.2 KB

# %%
# Check for missing vaules
print(df_train.isnull().sum())
# Out:
# OBJECTID       0
# Wildfire       0
# X              0
# Y              0
# TWI           23
# temp_july     12
# temp_max       6
# soilmois       6
# slope         23
# ndvi           3
# lulc           3
# dist_lake      2
# evt_aug        2
# elevation     23
# aspect        23
# dist_road      2
# dist_river     2
# pcp            6
# dtype: int64

# %%
# Check for missing vaules
print(df_test.isnull().sum())
# Out:
# OBJECTID       0
# Wildfire       0
# X              0
# Y              0
# TWI           10
# temp_july      3
# temp_max       3
# soilmois       3
# slope         10
# ndvi           3
# lulc           0
# dist_lake      0
# evt_aug        0
# elevation     10
# aspect        10
# dist_road      0
# dist_river     0
# pcp            3
# dtype: int64

# %%
df_train[df_train.isnull().any(axis= 1)]
# Out:
#        OBJECTID Wildfire             X             Y    TWI temp_july  \
# 6             7        1  2.355633e+06 -5.011467e+04    NaN       3.0
# 15044     15045        0  1.067970e+06 -3.218339e+05    NaN       NaN
# 15128     15129        0  9.084699e+05 -2.232339e+05  -46.0       NaN
# 15162     15163        0  1.098170e+06 -2.207339e+05  -46.0       NaN
# 15163     15164        0  1.098370e+06 -2.214339e+05  -46.0       NaN
# 15613     15614        0  1.658870e+06 -9.973389e+04    NaN       5.0
# 15618     15619        0  1.670270e+06 -1.042339e+05    NaN       5.0
# 15638     15639        0  4.105699e+05 -8.783389e+04  -46.0       NaN
# 15774     15775        0  4.469699e+05 -2.383389e+04 -219.0       NaN
# 15859     15860        0  1.694670e+06 -1.183389e+04    NaN       NaN
# 16040     16041        0  1.773970e+06  7.276611e+04    NaN       5.0
# 16094     16095        0  1.777370e+06  7.966611e+04    NaN       5.0
# 17374     17375        0  2.395070e+06  3.294661e+05    NaN       4.0
# 17608     17609        0  2.443470e+06  3.548661e+05  143.0       NaN
# 18123     18124        0 -1.922330e+06  4.317661e+05    NaN       4.0
# 18129     18130        0 -1.900230e+06  4.386661e+05    NaN       4.0
# 18131     18132        0 -1.895830e+06  4.295661e+05    NaN       4.0
# 18244     18245        0 -1.948330e+06  4.530661e+05    NaN       4.0
# 18245     18246        0 -1.950630e+06  4.524661e+05    NaN       4.0
# 19951     19952        0 -2.119930e+06  1.168066e+06    NaN       NaN
# 20234     20235        0 -2.043330e+06  1.300566e+06    NaN       2.0
# 20485     20486        0  9.630699e+05  1.354266e+06  -46.0       NaN
# 21642     21643        0  1.708470e+06  1.517566e+06    NaN       1.0
# 22149     22150        0  1.217570e+06  1.554966e+06    NaN       1.0
# 22180     22181        0  1.312270e+06  1.553266e+06  -46.0       NaN
# 26766     26767        0  4.900699e+05  2.191066e+06    NaN       NaN
# 28138     28139        0 -1.495130e+06  2.622266e+06    NaN       2.0
# 28204     28205        0 -1.496330e+06  2.653866e+06    NaN       1.0
# 28230     28231        0 -1.463930e+06  2.667966e+06    NaN       1.0
# 28259     28260        0 -1.459330e+06  2.678866e+06    NaN       1.0
# 28263     28264        0 -1.416130e+06  2.682266e+06    NaN       1.0
#
#       temp_max soilmois slope ndvi  lulc dist_lake evt_aug elevation aspect  \
# 6          5.0      3.0   NaN  5.0  11.0       5.0     5.0       NaN    NaN
# 15044      NaN      NaN   NaN  NaN   NaN       NaN     NaN       NaN    NaN
# 15128      5.0      4.0   2.0  5.0  11.0       1.0     5.0       2.0    3.0
# 15162      5.0      4.0   2.0  2.0  11.0       1.0     5.0       2.0    3.0
# 15163      5.0      4.0   2.0  2.0  11.0       1.0     5.0       2.0    4.0
# 15613      5.0      2.0   NaN  3.0   1.0       4.0     5.0       NaN    NaN
# 15618      5.0      2.0   NaN  3.0   1.0       4.0     5.0       NaN    NaN
# 15638      5.0      4.0   4.0  2.0   4.0       1.0     5.0       2.0    4.0
# 15774      5.0      3.0   4.0  4.0   4.0       1.0     5.0       3.0    3.0
# 15859      NaN      NaN   NaN  NaN  11.0       4.0     4.0       NaN    NaN
# 16040      5.0      2.0   NaN  5.0  11.0       4.0     4.0       NaN    NaN
# 16094      5.0      2.0   NaN  3.0  11.0       4.0     4.0       NaN    NaN
# 17374      5.0      4.0   NaN  4.0  11.0       5.0     5.0       NaN    NaN
# 17608      NaN      NaN   3.0  4.0   4.0       5.0     5.0       1.0    4.0
# 18123      5.0      5.0   NaN  5.0  11.0       4.0     5.0       NaN    NaN
# 18129      5.0      5.0   NaN  5.0  11.0       4.0     5.0       NaN    NaN
# 18131      5.0      5.0   NaN  4.0   2.0       4.0     5.0       NaN    NaN
# 18244      5.0      4.0   NaN  5.0  11.0       4.0     5.0       NaN    NaN
# 18245      5.0      4.0   NaN  5.0  11.0       4.0     5.0       NaN    NaN
# 19951      NaN      NaN   NaN  NaN   NaN       NaN     NaN       NaN    NaN
# 20234      4.0      2.0   NaN  3.0  11.0       4.0     1.0       NaN    NaN
# 20485      2.0      2.0   2.0  2.0   8.0       4.0     2.0       1.0    3.0
# 21642      2.0      1.0   NaN  1.0   NaN       4.0     1.0       NaN    NaN
# 22149      2.0      1.0   NaN  1.0   8.0       4.0     1.0       NaN    NaN
# 22180      NaN      NaN   2.0  1.0   8.0       4.0     1.0       1.0    3.0
# 26766      NaN      NaN   NaN  1.0  11.0       5.0     1.0       NaN    NaN
# 28138      1.0      1.0   NaN  2.0   4.0       5.0     2.0       NaN    NaN
# 28204      1.0      1.0   NaN  2.0  11.0       5.0     2.0       NaN    NaN
# 28230      1.0      1.0   NaN  2.0   3.0       5.0     2.0       NaN    NaN
# 28259      1.0      1.0   NaN  2.0   3.0       5.0     2.0       NaN    NaN
# 28263      1.0      1.0   NaN  2.0   3.0       5.0     2.0       NaN    NaN
#
#       dist_road dist_river  pcp
# 6           0.0        5.0  4.0
# 15044       NaN        NaN  NaN
# 15128       0.0        2.0  3.0
# 15162       1.0        1.0  3.0
# 15163       1.0        1.0  3.0
# 15613       0.0        3.0  3.0
# 15618       0.0        1.0  3.0
# 15638       0.0        2.0  2.0
# 15774       0.0        3.0  2.0
# 15859       0.0        3.0  NaN
# 16040       1.0        1.0  4.0
# 16094       0.0        2.0  4.0
# 17374       1.0        5.0  4.0
# 17608       2.0        5.0  NaN
# 18123       1.0        1.0  4.0
# 18129       1.0        3.0  4.0
# 18131       1.0        1.0  4.0
# 18244       0.0        1.0  4.0
# 18245       1.0        1.0  4.0
# 19951       NaN        NaN  NaN
# 20234       3.0        5.0  4.0
# 20485       4.0        5.0  2.0
# 21642       4.0        5.0  2.0
# 22149       4.0        5.0  2.0
# 22180       4.0        5.0  NaN
# 26766       4.0        4.0  NaN
# 28138       4.0        3.0  1.0
# 28204       4.0        3.0  1.0
# 28230       4.0        4.0  1.0
# 28259       4.0        4.0  1.0
# 28263       4.0        4.0  1.0

# %%
df_test[df_test.isnull().any(axis= 1)]
# Out:
#       OBJECTID Wildfire            X             Y    TWI temp_july temp_max  \
# 3779      3780        0  1099276.864 -2.210352e+05  -46.0       NaN      5.0
# 3889      3890        0  1656776.864 -1.078352e+05    NaN       5.0      5.0
# 3906      3907        0  1667476.864 -8.523515e+04    NaN       5.0      5.0
# 3907      3908        0  1670876.864 -8.873515e+04    NaN       5.0      5.0
# 4234      4235        0  2236376.864  2.618648e+05    NaN       5.0      5.0
# 4517      4518        0 -1902023.136  4.328648e+05    NaN       4.0      5.0
# 4548      4549        0 -1947223.136  4.487648e+05    NaN       4.0      5.0
# 4840      4841        0  2942776.864  7.680648e+05    NaN       2.0      5.0
# 4899      4900        0  2861376.864  8.542648e+05    NaN       3.0      5.0
# 4922      4923        0  2829976.864  8.940648e+05    NaN       4.0      5.0
# 4929      4930        0  2827276.864  8.998648e+05  143.0       NaN      5.0
# 5087      5088        0  1500476.864  1.335165e+06  143.0       NaN      NaN
# 5407      5408        0  1709776.864  1.513365e+06 -219.0       1.0      NaN
# 5546      5547        0  1207476.864  1.552665e+06    NaN       1.0      2.0
# 7051      7052        0 -1463623.136  2.639265e+06  -46.0       1.0      NaN
#
#      soilmois slope ndvi lulc dist_lake evt_aug elevation aspect dist_road  \
# 3779      4.0   2.0  2.0   11         1       5       2.0    4.0         1
# 3889      2.0   NaN  3.0    1         4       5       NaN    NaN         0
# 3906      2.0   NaN  3.0    1         4       5       NaN    NaN         0
# 3907      2.0   NaN  3.0   11         4       5       NaN    NaN         1
# 4234      3.0   NaN  5.0    4         5       5       NaN    NaN         1
# 4517      5.0   NaN  5.0    4         4       5       NaN    NaN         1
# 4548      4.0   NaN  5.0    4         4       5       NaN    NaN         0
# 4840      2.0   NaN  5.0   11         5       4       NaN    NaN         2
# 4899      2.0   NaN  5.0    3         5       4       NaN    NaN         0
# 4922      3.0   NaN  5.0    4         5       4       NaN    NaN         0
# 4929      3.0   5.0  5.0    6         5       4       1.0    3.0         0
# 5087      NaN   4.0  NaN    8         4       2       1.0    3.0         4
# 5407      NaN   5.0  NaN    5         4       1       2.0    5.0         4
# 5546      1.0   NaN  1.0   11         4       1       NaN    NaN         4
# 7051      NaN   1.0  NaN   11         5       2       1.0    1.0         4
#
#      dist_river  pcp
# 3779          1  3.0
# 3889          3  3.0
# 3906          2  3.0
# 3907          1  3.0
# 4234          5  4.0
# 4517          1  4.0
# 4548          1  4.0
# 4840          5  4.0
# 4899          5  4.0
# 4922          4  4.0
# 4929          4  4.0
# 5087          4  NaN
# 5407          5  NaN
# 5546          5  2.0
# 7051          3  NaN

# %%
# Drop rows with null values for TRAINING DATA
New_df_train = df_train.dropna()

# %%
New_df_train[New_df_train.isnull().any(axis= 1)]
# Out:
# Empty DataFrame
# Columns: [OBJECTID, Wildfire, X, Y, TWI, temp_july, temp_max, soilmois, slope, ndvi, lulc, dist_lake, evt_aug, elevation, aspect, dist_road, dist_river, pcp]
# Index: []

# %%
# Drop rows with null values for TESTING DATA
New_df_test = df_test.dropna()

# %%
New_df_test[New_df_test.isnull().any(axis= 1)]
# Out:
# Empty DataFrame
# Columns: [OBJECTID, Wildfire, X, Y, TWI, temp_july, temp_max, soilmois, slope, ndvi, lulc, dist_lake, evt_aug, elevation, aspect, dist_road, dist_river, pcp]
# Index: []

# %%
New_df_train.head()
# Out:
#    OBJECTID Wildfire             X             Y    TWI temp_july temp_max  \
# 0         1        1  9.779328e+05 -171014.66810   -6.0       4.0      5.0
# 1         2        1  1.347033e+06  -80014.66811   -6.0       4.0      5.0
# 2         3        1  9.444328e+05  -50014.66811  129.0       4.0      5.0
# 3         4        1  9.470328e+05  -50814.66811   -6.0       4.0      5.0
# 4         5        1  9.414328e+05  -51414.66811  -46.0       4.0      5.0
#
#   soilmois slope ndvi lulc dist_lake evt_aug elevation aspect dist_road  \
# 0      4.0   3.0  5.0  4.0       2.0     5.0       3.0    4.0       2.0
# 1      3.0   3.0  5.0  4.0       4.0     5.0       2.0    3.0       2.0
# 2      3.0   2.0  5.0  4.0       4.0     5.0       3.0    2.0       2.0
# 3      3.0   2.0  5.0  4.0       4.0     5.0       3.0    5.0       2.0
# 4      3.0   2.0  5.0  4.0       4.0     5.0       3.0    5.0       2.0
#
#   dist_river  pcp
# 0        4.0  3.0
# 1        4.0  3.0
# 2        4.0  3.0
# 3        4.0  3.0
# 4        4.0  3.0

# %%
New_df_test.head()
# Out:
#    OBJECTID Wildfire             X             Y    TWI temp_july temp_max  \
# 0         1        1  1.104417e+06 -41066.374270 -219.0       4.0      5.0
# 1         2        1  2.347017e+06 -47066.374270   -6.0       3.0      5.0
# 2         3        1  2.353017e+06 -47366.374270   -6.0       3.0      5.0
# 3         4        1  7.265169e+05   9933.625731  143.0       3.0      4.0
# 4         5        1  7.247169e+05   6933.625731  143.0       3.0      4.0
#
#   soilmois slope ndvi lulc dist_lake evt_aug elevation aspect dist_road  \
# 0      3.0   4.0  5.0    4         4       5       3.0    4.0         2
# 1      3.0   2.0  5.0    4         5       4       1.0    4.0         0
# 2      3.0   2.0  5.0    4         5       5       1.0    4.0         0
# 3      3.0   4.0  5.0    4         3       5       3.0    3.0         1
# 4      3.0   4.0  5.0    4         3       5       3.0    3.0         0
#
#   dist_river  pcp
# 0          4  3.0
# 1          5  4.0
# 2          5  4.0
# 3          4  3.0
# 4          4  3.0

# %%
# Drop Object ID from Training data
columns_to_drop = ['OBJECTID']
New_df_train = New_df_train.drop(columns= columns_to_drop)

# %%
# Drop column "Object ID" from testing data
columns_to_drop = ['OBJECTID']
New_df_test = New_df_test.drop(columns= columns_to_drop)

# %%
New_df_train.head()
# Out:
#   Wildfire             X             Y    TWI temp_july temp_max soilmois  \
# 0        1  9.779328e+05 -171014.66810   -6.0       4.0      5.0      4.0
# 1        1  1.347033e+06  -80014.66811   -6.0       4.0      5.0      3.0
# 2        1  9.444328e+05  -50014.66811  129.0       4.0      5.0      3.0
# 3        1  9.470328e+05  -50814.66811   -6.0       4.0      5.0      3.0
# 4        1  9.414328e+05  -51414.66811  -46.0       4.0      5.0      3.0
#
#   slope ndvi lulc dist_lake evt_aug elevation aspect dist_road dist_river  pcp
# 0   3.0  5.0  4.0       2.0     5.0       3.0    4.0       2.0        4.0  3.0
# 1   3.0  5.0  4.0       4.0     5.0       2.0    3.0       2.0        4.0  3.0
# 2   2.0  5.0  4.0       4.0     5.0       3.0    2.0       2.0        4.0  3.0
# 3   2.0  5.0  4.0       4.0     5.0       3.0    5.0       2.0        4.0  3.0
# 4   2.0  5.0  4.0       4.0     5.0       3.0    5.0       2.0        4.0  3.0

# %%
New_df_test.head()
# Out:
#   Wildfire             X             Y    TWI temp_july temp_max soilmois  \
# 0        1  1.104417e+06 -41066.374270 -219.0       4.0      5.0      3.0
# 1        1  2.347017e+06 -47066.374270   -6.0       3.0      5.0      3.0
# 2        1  2.353017e+06 -47366.374270   -6.0       3.0      5.0      3.0
# 3        1  7.265169e+05   9933.625731  143.0       3.0      4.0      3.0
# 4        1  7.247169e+05   6933.625731  143.0       3.0      4.0      3.0
#
#   slope ndvi lulc dist_lake evt_aug elevation aspect dist_road dist_river  pcp
# 0   4.0  5.0    4         4       5       3.0    4.0         2          4  3.0
# 1   2.0  5.0    4         5       4       1.0    4.0         0          5  4.0
# 2   2.0  5.0    4         5       5       1.0    4.0         0          5  4.0
# 3   4.0  5.0    4         3       5       3.0    3.0         1          4  3.0
# 4   4.0  5.0    4         3       5       3.0    3.0         0          4  3.0

# %% [markdown]
# ## Multi-Collinearity Analysis

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def calculate_vif(df):

    vifs = [variance_inflation_factor(New_df_train.values, i) for i in range(New_df_train.shape[1])]
    tolerance = [1/vif for vif in vifs]

    vif_data = pd.DataFrame(index=New_df_train.columns)
    vif_data['VIF'] = vifs
    vif_data['Tolerance'] = tolerance

    return vif_data

# Calculate VIF 
vif_data = calculate_vif(New_df_train)

print(vif_data)
# Out:
#                   VIF  Tolerance
# Wildfire     4.838168   0.206690
# X            3.503787   0.285405
# Y           21.699731   0.046084
# TWI          1.426056   0.701235
# temp_july   26.158782   0.038228
# temp_max    48.349064   0.020683
# soilmois     9.106782   0.109808
# slope       15.809214   0.063254
# ndvi        21.576294   0.046347
# lulc         8.944670   0.111798
# dist_lake   22.144932   0.045157
# evt_aug     38.087221   0.026256
# elevation   18.777529   0.053255
# aspect       8.952495   0.111701
# dist_road   15.817948   0.063219
# dist_river  24.268020   0.041206
# pcp         18.342987   0.054517

# %%
def plot_vif(vif_data):
    # Set up the matplotlib figure
    f, ax = plt.subplots(figsize=(12, 8))

    # Plot the VIF values
    sns.barplot(x=vif_data['VIF'], y=vif_data.index, palette="vlag", ax=ax)
    ax.axvline(x=25, color="red", linestyle="--")  # Add a vertical line at VIF = 30
    ax.set_title('VIF Scores', fontweight='bold', fontsize=15)
    ax.set_xlabel('VIF Value', fontweight='bold', fontsize=12)
    ax.set_ylabel('Feature', fontweight='bold', fontsize=12)

    # Display the plot
    plt.show()

plot_vif(vif_data)

# %% [markdown]
# ## Feature Importance

# %%
from sklearn.ensemble import RandomForestClassifier
# Create the feature matrix X and the target variable y

X = New_df_train[
    ['X', 'Y', 'TWI', 'temp_july', 'temp_max', 'soilmois', 'slope',
     'ndvi', 'lulc', 'dist_lake', 'evt_aug', 'elevation', 'aspect', 'dist_road', 'dist_river', 'pcp']
]
y = New_df_train['Wildfire']

# Initialize the random forest classifier
rf = RandomForestClassifier()

# Fit the classifier to the data
rf.fit(X, y)

# Get feature importances
importances = rf.feature_importances_

# Create a DataFrame with feature names and importances
feature_importance = pd.DataFrame({'Feature': X.columns, 'Importance': importances})

# Calculate the sum of importances
total_importance = feature_importance['Importance'].sum()

# Calculate the weights by dividing each importance by the total importance
feature_importance['Weight'] = feature_importance['Importance'] / total_importance

# Sort the DataFrame by importance in descending order
feature_importance = feature_importance.sort_values('Importance', ascending=False)

# Print the feature importances with weights
print(feature_importance)
# Out:
#        Feature  Importance    Weight
# 7         ndvi    0.236480  0.236480
# 10     evt_aug    0.135840  0.135840
# 4     temp_max    0.135637  0.135637
# 8         lulc    0.122925  0.122925
# 1            Y    0.074106  0.074106
# 0            X    0.059322  0.059322
# 3    temp_july    0.058650  0.058650
# 13   dist_road    0.047530  0.047530
# 15         pcp    0.035375  0.035375
# 11   elevation    0.028440  0.028440
# 5     soilmois    0.020058  0.020058
# 9    dist_lake    0.015172  0.015172
# 6        slope    0.013160  0.013160
# 14  dist_river    0.008642  0.008642
# 12      aspect    0.005270  0.005270
# 2          TWI    0.003395  0.003395

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the color palette
palette = sns.cubehelix_palette(len(feature_importance['Feature']), start=2, rot=0, dark=0.2, light=0.8, reverse=True)

# Create a graph
plt.figure(figsize=(10, 6))
bars = plt.barh(feature_importance['Feature'], feature_importance['Weight'], color=palette)
plt.xlabel('Weight')
plt.ylabel('Feature')
plt.title('Feature Importance with Weights')
plt.gca().invert_yaxis()  # Invert the y-axis for better visualization

# Show the graph
plt.show()

# %% [markdown]
# ## SHAP value

# %%
import shap

# Assuming rf is your trained RandomForestClassifier and X is your feature matrix

# Create a SHAP explainer object
explainer = shap.TreeExplainer(rf)
shap_values = explainer.shap_values(X)

# Plot SHAP values (summary plot for overall feature importance)
shap.summary_plot(shap_values[1], X)  # Index 1 for class 1 ('Wildfire') if it's a binary classification

# Alternatively, for a simpler bar plot of feature importance
shap.summary_plot(shap_values, X, plot_type="bar")

# %% [markdown]
# ## Outlier Detection

# %%
from pyod.models.knn import KNN

# Selecting relevant features for outlier detection
columns_for_outlier_detection = [
    'temp_july', 'temp_max', 'soilmois', 'slope', 'ndvi',
    'lulc', 'dist_lake', 'evt_aug', 'elevatoin', 'aspect', 'dist_road', 'dist_river', 'pcp'
]

# Extracting the relevant columns from the DataFrame
X = New_df_train[columns_for_outlier_detection].values

# Train the KNN outlier detection model
knn_model = KNN(contamination=0.05)  # Set the desired contamination level
knn_model.fit(X)

# Predict the outlier scores and labels
outlier_scores = knn_model.decision_scores_
outlier_labels = knn_model.predict(X)

# Add the outlier scores and labels to the DataFrame
df_train_dropped['outlier_scores'] = outlier_scores
df_train_dropped['outlier_labels'] = outlier_labels

# Print the instances flagged as outliers
outliers = df_train_cleaned[df_train_dropped['outlier_labels'] == 1]
print("Outliers:")
print(outliers)

# Remove the outlier instances if desired
df_train_Filter = df_train_dropped[df_train_dropped['outlier_labels'] == 0]

# %%
from sklearn.ensemble import IsolationForest

# Selecting relevant features for outlier detection
columns_for_outlier_detection = [
    'temp_july', 'temp_max', 'soilmois', 'slope', 'ndvi',
    'lulc', 'dist_lake', 'evt_aug', 'elevatoin', 'aspect', 'dist_road', 'dist_river', 'pcp'
]
# Extracting the relevant columns from the DataFrame
X = New_df_train[columns_for_outlier_detection].values

# Train the Isolation Forest outlier detection model
isolation_forest = IsolationForest(contamination=0.05)  # Set the desired contamination level
isolation_forest.fit(X)

# Predict the outlier labels
outlier_labels = isolation_forest.predict(X)

# Add the outlier labels to the DataFrame
df_train_dropped['outlier_labels'] = outlier_labels

# Print the instances flagged as outliers
outliers = df_train_dropped[df_train_dropped['outlier_labels'] == -1]
print("Outliers:")
print(outliers)

# Remove the outlier instances if desired
df_train_Filter2 = df_train_dropped[df_train_dropped['outlier_labels'] == 1]
df_train_Filter2.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## One Hot encoding for Categorical Features

# %% [markdown]
# ## Training ML models

# %% [markdown]
# ### Random Forest

# %% [markdown]
# ### RF-Grid Search

# %% [markdown]
# ### RF-PSO

# %% [markdown]
# ## Training DL models

# %% [markdown]
# ### CNN

# %% [markdown]
# ### CNN-LSTM

# %% [markdown]
# ### CNN-LSTM-PSO

# %% [markdown]
# ### CNN-LSTM-Grid Search

# %% [markdown]
# ### CNN-Grid Search

# %% [markdown]
# ### CNN- PSO
