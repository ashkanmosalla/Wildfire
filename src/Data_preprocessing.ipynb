# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('DATA_without_classify.csv')

# %%
df.head()
# Out:
#    Id            X            Y  lake  road  river   TWI2_1  temp_july2  \
# 0   1 -565155.8849  371574.0348     4     2      5  13.4730        24.9
# 1   1 -490208.7562  371619.6100     3     1      5  14.3289        24.7
# 2   1 -814589.1191  513177.4706     4     2      4  12.3863        24.2
# 3   1 -467596.1093  454916.8753     3     1      4  14.8397        25.0
# 4   1 -738400.4433  508255.4875     4     1      3  12.7564        24.9
#
#    slope2   aspect2  LULC2   NDVI2     pcp2  soilmois2  DEM_masked  evt_aug_1
# 0  0.0646  326.3100      2  0.2695  470.974    42.6947         602          5
# 1  0.1646  337.6200      2  0.3009  535.897    59.4827         540          4
# 2  0.3828  259.2160      2  0.2967  474.231    26.7754         699          5
# 3  0.1646   22.3801      2  0.2928  493.821    51.3152         314          4
# 4  0.1322  118.3010      4  0.4041  433.410    31.6701         503          4

# %%
df['Id'].value_counts()
# Out:
# 1    6000
# 0    6000
# Name: Id, dtype: int64

# %%
df.shape
# Out:
# (12000, 16)

# %%
df = pd.read_csv(
    'DATA_without_classify.csv',
    names= [
        'Wildfire',
        'X',
        'Y',
        'Distance_lake',
        'Distance_road',
        'Distance_river',
        'TWI',
        'July_temperature',
        'Slope',
        'Aspect',
        'LULC',
        'NDVI',
        'Precipitation',
        'Soil_moisture',
        'Elevation',
        'August_evt'
    ],
    header= 0
)

# %%
df.head()
# Out:
#    Wildfire            X            Y  Distance_lake  Distance_road  \
# 0         1 -565155.8849  371574.0348              4              2
# 1         1 -490208.7562  371619.6100              3              1
# 2         1 -814589.1191  513177.4706              4              2
# 3         1 -467596.1093  454916.8753              3              1
# 4         1 -738400.4433  508255.4875              4              1
#
#    Distance_river      TWI  July_temperature   Slope    Aspect  LULC    NDVI  \
# 0               5  13.4730              24.9  0.0646  326.3100     2  0.2695
# 1               5  14.3289              24.7  0.1646  337.6200     2  0.3009
# 2               4  12.3863              24.2  0.3828  259.2160     2  0.2967
# 3               4  14.8397              25.0  0.1646   22.3801     2  0.2928
# 4               3  12.7564              24.9  0.1322  118.3010     4  0.4041
#
#    Precipitation  Soil_moisture  Elevation  August_evt
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Wildfire          12000 non-null  int64
#  1   X                 12000 non-null  float64
#  2   Y                 12000 non-null  float64
#  3   Distance_lake     12000 non-null  int64
#  4   Distance_road     12000 non-null  int64
#  5   Distance_river    12000 non-null  int64
#  6   TWI               12000 non-null  float64
#  7   July_temperature  12000 non-null  float64
#  8   Slope             12000 non-null  float64
#  9   Aspect            12000 non-null  float64
#  10  LULC              12000 non-null  int64
#  11  NDVI              12000 non-null  float64
#  12  Precipitation     12000 non-null  float64
#  13  Soil_moisture     12000 non-null  float64
#  14  Elevation         12000 non-null  int64
#  15  August_evt        12000 non-null  int64
# ...

# %%
df['Distance_lake'].value_counts()
# Out:
# 4    5662
# 3    2879
# 2    1173
# 5    1145
# 1    1124
# 0      17
# Name: Distance_lake, dtype: int64

# %%
df['Distance_river'].value_counts()
# Out:
# 4    4610
# 5    3259
# 3    3064
# 2     626
# 1     424
# 0      17
# Name: Distance_river, dtype: int64

# %%
df['Distance_road'].value_counts()
# Out:
# 3    3562
# 4    2814
# 2    2466
# 1    2326
# 0     832
# Name: Distance_road, dtype: int64

# %%
df = df.astype(
    {
        'Wildfire': 'category',
        'Distance_lake': 'category',
        'Distance_road': 'category',
        'Distance_river': 'category',
        'LULC': 'category',
        'August_evt': 'category'

    }
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Wildfire          12000 non-null  category
#  1   X                 12000 non-null  float64
#  2   Y                 12000 non-null  float64
#  3   Distance_lake     12000 non-null  category
#  4   Distance_road     12000 non-null  category
#  5   Distance_river    12000 non-null  category
#  6   TWI               12000 non-null  float64
#  7   July_temperature  12000 non-null  float64
#  8   Slope             12000 non-null  float64
#  9   Aspect            12000 non-null  float64
#  10  LULC              12000 non-null  category
#  11  NDVI              12000 non-null  float64
#  12  Precipitation     12000 non-null  float64
#  13  Soil_moisture     12000 non-null  float64
#  14  Elevation         12000 non-null  int64
#  15  August_evt        12000 non-null  category
# ...

# %%
df.head()
# Out:
#   Wildfire            X            Y Distance_lake Distance_road  \
# 0        1 -565155.8849  371574.0348             4             2
# 1        1 -490208.7562  371619.6100             3             1
# 2        1 -814589.1191  513177.4706             4             2
# 3        1 -467596.1093  454916.8753             3             1
# 4        1 -738400.4433  508255.4875             4             1
#
#   Distance_river      TWI  July_temperature   Slope    Aspect LULC    NDVI  \
# 0              5  13.4730              24.9  0.0646  326.3100    2  0.2695
# 1              5  14.3289              24.7  0.1646  337.6200    2  0.3009
# 2              4  12.3863              24.2  0.3828  259.2160    2  0.2967
# 3              4  14.8397              25.0  0.1646   22.3801    2  0.2928
# 4              3  12.7564              24.9  0.1322  118.3010    4  0.4041
#
#    Precipitation  Soil_moisture  Elevation August_evt
# 0        470.974        42.6947        602          5
# ...

# %%
df[df.isnull().any(axis= 1)]
# Out:
# Empty DataFrame
# Columns: [Wildfire, X, Y, Distance_lake, Distance_road, Distance_river, TWI, July_temperature, Slope, Aspect, LULC, NDVI, Precipitation, Soil_moisture, Elevation, August_evt]
# Index: []

# %%
df
# Out:
#       Wildfire             X             Y Distance_lake Distance_road  \
# 0            1 -5.651559e+05  3.715740e+05             4             2
# 1            1 -4.902088e+05  3.716196e+05             3             1
# 2            1 -8.145891e+05  5.131775e+05             4             2
# 3            1 -4.675961e+05  4.549169e+05             3             1
# 4            1 -7.384004e+05  5.082555e+05             4             1
# ...        ...           ...           ...           ...           ...
# 11995        0 -1.680890e+06  2.620365e+06             5             3
# 11996        0 -1.648350e+06  2.605284e+06             5             3
# 11997        0 -1.621360e+06  2.652115e+06             5             3
# 11998        0 -1.544370e+06  2.656084e+06             5             3
# 11999        0 -1.434830e+06  2.602902e+06             4             4
#
#       Distance_river      TWI  July_temperature   Slope    Aspect LULC  \
# ...
